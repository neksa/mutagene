# %%
import pickle

# %%
with open("/Users/agoncear/Downloads/scores/TP53.mgaentropy.pickle", 'br') as f:
    l = pickle.load(f, encoding = 'bytes')
print(len(l))
print(l)
# Out:
# 393
# [0.71572265 0.98351638 1.33394771 2.33666585 1.64152499 1.72881006
#  1.20274986 1.87337891 1.80312168 2.31677658 1.10627171 1.75433086
#  0.52256024 0.50911154 0.3189326  0.52256024 0.69778989 0.69778989
#  0.3189326  1.01546211 1.51430311 0.82994364 0.3189326  1.99721604
#  0.35785218 0.36922724 0.58507351 1.95881047 1.18721639 1.76623075
#  1.93698652 0.38140231 1.22433332 1.38424892 2.42488729 2.28328156
#  1.69224953 2.24058946 1.91159786 1.79781778 1.85467987 1.80801139
#  0.58507351 1.72404627 1.554795   1.98196246 2.43094749 1.72911955
#  1.77643838 2.4748577  2.13560349 2.71194023 1.15429535 1.40725373
#  2.46201828 1.2926133  0.93475522 1.03019847 1.51304611 1.48031971
#  2.12238543 1.0912997  1.54636433 2.53045271 2.23203332 1.67656432
#  2.13963548 2.06305651 2.3342672  1.85591259 2.14566688 1.56558805
#  2.92799269 2.15627211 1.49114308 2.16408827 1.51192852 1.72651723
#  1.81242499 0.95574002 2.31079401 1.39820481 1.72325472 1.30733794
# ...

# %%
import pprint
with open("/Users/agoncear/Downloads/scores/TP53.vest.pickle", 'br') as f:
    l = pickle.load(f)
pprint.pprint(l)
# Out:
# {1: {'M': {'I': 0.718,
#            'K': 0.78,
#            'L': 0.8270000000000001,
#            'R': 0.519,
#            'T': 0.731,
#            'V': 0.792}},
#  2: {'E': {'A': 0.282,
#            'D': 0.094,
#            'G': 0.281,
#            'K': 0.315,
#            'Q': 0.106,
#            'V': 0.379}},
#  3: {'E': {'A': 0.10300000000000001,
#            'D': 0.081,
#            'G': 0.134,
#            'K': 0.19699999999999998,
#            'Q': 0.109,
#            'V': 0.268}},
#  4: {'P': {'A': 0.084,
#            'L': 0.096,
#            'Q': 0.09,
#            'R': 0.10800000000000001,
#            'S': 0.043,
#            'T': 0.059000000000000004}},
#  5: {'Q': {'E': 0.15,
#            'H': 0.122,
#            'K': 0.11800000000000001,
#            'L': 0.145,
#            'P': 0.11900000000000001,
#            'R': 0.147}},
#  6: {'S': {'A': 0.07400000000000001,
#            'L': 0.094,
#            'P': 0.10400000000000001,
#            'T': 0.064}},
# ...
